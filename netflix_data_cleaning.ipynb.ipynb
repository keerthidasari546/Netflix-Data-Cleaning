# %%
import pandas as pd

df = pd.read_csv("netflix_titles.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5488/989696722.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("netflix_titles.csv")
#       4 df.head()
#
# ...

# %%
# !unzip -l netflix_titles.csv.zip
# Out:
# unzip:  cannot find or open netflix_titles.csv.zip, netflix_titles.csv.zip.zip or netflix_titles.csv.zip.ZIP.

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'sample_data']

# %%
import os
print(os.listdir('/content'))
# Out:
# ['.config', 'sample_data']

# %%
import pandas as pd

df = pd.read_csv("/content/netflix_titles.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_5488/1601353969.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("/content/netflix_titles.csv")
#       4 df.head()
#
# ...

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
import os

print(os.path.exists("/content/netflix_titles.csv"))
# Out:
# False

# %%
import pandas as pd

df = pd.read_csv("/netflix_titles.csv")
df.head()
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
# Check dataset information
df.info()

# Check missing values
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# ...

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df["director"] = df["director"].fillna("Unknown")
df["cast"] = df["cast"].fillna("Not Available")
df["country"] = df["country"].fillna("Unknown")

# %%
df = df.dropna(subset=["date_added"])

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
df["type"] = df["type"].str.title()
df["country"] = df["country"].str.title().str.strip()

# %%
df["date_added"] = df["date_added"].str.strip()

df["date_added"] = pd.to_datetime(
    df["date_added"],
    format="mixed",
    errors="coerce"
)

df["date_added"] = df["date_added"].dt.strftime("%d-%m-%Y")

# %%
df[["title", "date_added"]].head()
# Out:
#                    title  date_added
# 0   Dick Johnson Is Dead  25-09-2021
# 1          Blood & Water  24-09-2021
# 2              Ganglands  24-09-2021
# 3  Jailbirds New Orleans  24-09-2021
# 4           Kota Factory  24-09-2021

# %%
df.dtypes
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %%
df.to_csv("cleaned_netflix_dataset.csv", index=False)

print("Dataset cleaned successfully!")
# Out:
# Dataset cleaned successfully!

# %%
import os
print(os.listdir("/"))
# Out:
# ['lib', 'mnt', 'proc', 'srv', 'opt', 'bin', 'var', 'boot', 'libx32', 'lib32', 'usr', 'tmp', 'run', 'etc', 'dev', 'home', 'media', 'lib64', 'sbin', 'root', 'sys', 'kaggle', 'netflix_titles.csv.zip', 'netflix_titles.csv', '.ipynb_checkpoints', 'content', '.dockerenv', 'tools', 'datalab', 'python-apt', 'python-apt.tar.xz']

# %%
import os
print(os.listdir("/content"))
# Out:
# ['.config', 'cleaned_netflix_dataset.csv', 'sample_data']

# %%
from google.colab import files

files.download("/content/cleaned_netflix_dataset.csv")
